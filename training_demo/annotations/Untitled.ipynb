# %%
import tensorflow as tf

for example in tf.python_io.tf_record_iterator("train.record"):
    print(tf.train.Example.FromString(example))
    #print(count(example))
# Out:
# features {
#   feature {
#     key: "image/encoded"
#     value {
#       bytes_list {
# ...

# %%
filenames = ['test.record']
raw_dataset = tf.data.TFRecordDataset('test.record')
raw_dataset
for raw_record in raw_dataset.take(10):
    print(repr(raw_record))
# Out:
# <tf.Tensor 'IteratorGetNext_111555:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111556:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111557:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111558:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111559:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111560:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111561:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111562:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111563:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111564:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111565:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111566:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111567:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111568:0' shape=() dtype=string>
# <tf.Tensor 'IteratorGetNext_111569:0' shape=() dtype=string>
# ...
